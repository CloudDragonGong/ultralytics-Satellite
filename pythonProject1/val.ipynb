# %%
import os

from ultralytics import YOLO


model = YOLO('/Users/mac/data/workspace/ultralytics-Satellite/runs/segment/train9/weights/best.pt')
results = model.predict('/Volumes/My Passport/dataset/UESD/yolov11/train/images/00040.png',save = True,project = 'runs/detect',name = 'UESD')
# Out:
# image 1/1 /Volumes/My Passport/dataset/UESD/yolov11/train/images/00040.png: 448x640 4 solar panels, 1 instrument, 193.7ms
# Speed: 1.3ms preprocess, 193.7ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/UESD

# %%
from PIL import Image
from matplotlib import pyplot as plt
image = Image.open('/Volumes/My Passport/dataset/UESD/yolov11/train/images/00040.png')
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
result_image = Image.open('/Users/mac/data/workspace/ultralytics-Satellite/pythonProject1/runs/detect/UESD/00040.jpg')
plt.imshow(result_image)
plt.axis('off')
plt.show()
